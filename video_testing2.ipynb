# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the trained model
model = load_model("phone_identification_2.keras")

# Define class indices (use the same indices as in training)
class_indices = {'directory_apple4': 1, 'directory_apple5': 2, 'directory_apple6': 3, 'directory_huawei': 4,
                 'directory_Lenovo': 5, 'directory_Lg': 6, 'directory_microsoft_lumia': 7, 'directory_samsung': 8,
                 'directory_samsung_galaxy': 9, 'directory_Sony': 10}

# Function to preprocess the new image
def preprocess_image(file_path):
    img = cv2.imread(file_path)
    img = cv2.resize(img, (128, 128))
    img = img / 255.0  # Normalize the image
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# Function to get the class label from the predicted class probabilities
def get_class_label(predictions):
    class_index = np.argmax(predictions)
    class_label = class_indices_reverse[class_index + 1]  # Adding 1 because class indices start from 1
    return class_label

# Map class indices to class labels
class_indices_reverse = {v: k for k, v in class_indices.items()}

# Path to the new image file
new_image_path = r"C:\Users\rineesha\Documents\Project\directory\directory_Lg\frame_21.jpg"

# Preprocess the new image
new_image = preprocess_image(new_image_path)

# Use the model to predict the class
predictions = model.predict(new_image)

# Get the predicted class label
predicted_class = get_class_label(predictions)

print("Predicted Class:", predicted_class)
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Predicted Class: directory_microsoft_lumia

# %%
import os
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model

# Define your dataset directory
dataset_dir = "C:\\Users\\rineesha\\Documents\\Project\\directory\\"

# Define image size and batch size
img_size = (128, 128)
batch_size = 32
print("Training Class Indices:", train_generator.class_indices)

# Create an ImageDataGenerator for data augmentation
datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=60,
    width_shift_range=0.2,
    height_shift_range=0.2
)

# Generate training data from the dataset directory
train_generator = datagen.flow_from_directory(
    dataset_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'

)

# Load the trained model
model = load_model("phone_model_source_identification_3.keras")

# Function to preprocess the new image
def preprocess_image(file_path):
    img = cv2.imread(file_path)
    img = cv2.resize(img, (128, 128))
    img = img / 255.0  # Normalize the image
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# Function to get the class label from the predicted class probabilities
def get_class_label(predictions):
    class_index = np.argmax(predictions)
    class_label = list(train_generator.class_indices.keys())[class_index]
    print("Training Class Indices:", train_generator.class_indices)

    return class_label

# Path to the new image file
new_image_path ="C:\\Users\\rineesha\\Documents\\Project\\directory\\directory_Lg\\frame_21.jpg"

# Preprocess the new image
new_image = preprocess_image(new_image_path)

# Use the model to predict the class
predictions = model.predict(new_image)
print(predictions)

# Get the predicted class label
predicted_class = get_class_label(predictions)

print("Predicted Class:", predicted_class)
# Out:
# Training Class Indices: {'directory_Lenovo': 0, 'directory_Lg': 1, 'directory_Sony': 2, 'directory_apple4': 3, 'directory_apple5': 4, 'directory_apple6': 5, 'directory_huawei': 6, 'directory_microsoft_lumia': 7, 'directory_samsung': 8, 'directory_samsung_galaxy': 9}
# Found 730 images belonging to 10 classes.
# 1/1 [==============================] - 0s 210ms/step
# [[0.0000000e+00 6.0383932e-22 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 1.1897829e-15 0.0000000e+00 0.0000000e+00 0.0000000e+00]]
# Training Class Indices: {'directory_Lenovo': 0, 'directory_Lg': 1, 'directory_Sony': 2, 'directory_apple4': 3, 'directory_apple5': 4, 'directory_apple6': 5, 'directory_huawei': 6, 'directory_microsoft_lumia': 7, 'directory_samsung': 8, 'directory_samsung_galaxy': 9}
# Predicted Class: directory_Sony
